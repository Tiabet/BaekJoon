# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 경로를 탐색하는 문제처럼 보인다. 이런 류의 문제는 동적 프로그래밍을 통해 풀어야 정답으로 인정될 것이다.

# %%
n = int(input())

for _ in range(n):
    num = int(input())
    dp = [1]*(num+1)
    dp[1]=1
    
    if num>1:
         dp[2]=2
    
    for i in range(3,num+1):
        dp[i]=dp[i-1]+dp[i-2]+dp[i-3]
    
    print(dp[num])
# Out:
# 3
# 4
# 7
# 7
# 44
# 10
# 274
