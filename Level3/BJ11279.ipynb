# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# max heap을 구현하는 문제다. 데이터구조론 시간에 배운 적이 있으므로 어렵지 않게 풀 수 있을 것 같다. 게다가 구현 전 찾아보니 파이썬엔 heapq라는 모듈이 있어 쉽게 힙을 구현할 수 있었다. 참 편리하다.

# %%
import sys
import heapq

input = sys.stdin.readline

n = int(input())
heap = []

for i in range(n):
    num = int(input())
    if num == 0:
        if heap :
            print(-heapq.heappop(heap))
        else :
            print(0)
    else:
        heapq.heappush(heap,(-1)*num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8052\1164938193.py in <module>
#       4 input = sys.stdin.readline
#       5
# ----> 6 n = int(input())
#       7 heap = []
#       8
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# heapq에는 최소값을 반환하는 heappop이 존재하기 때문에, (min heap) max heap을 구현하기 위해선 음수를 곱해주는 조치가 필요함을 배울 수 있었다.
