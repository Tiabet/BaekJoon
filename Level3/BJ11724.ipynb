# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 역시나 DFS, BFS 를 응용한 그래프 문제다. Level 3엔 참 이런 문제가 많은 것 같다. 개인적으론 DFS가 좀 더 쉬운 것 같아서 DFS로 풀어보겠다.

# %%
import sys
sys.setrecursionlimit(10**7)
input = sys.stdin.readline

n, m = map(int,input().split())

graph = [[] for _ in range(n+1)]
visited = [0] * (n+1)

for _ in range(m):
    x, y = map(int, input().split())
    graph[x].append(y)
    graph[y].append(x)

def DFS(x):
    visited[x]=1
    for i in graph[x]:
        if visited[i]==0:
            visited[i]==1
            DFS(i)

count=0
for i in range(1, n+1):
    if visited[i] == 0:
        count+=1
        dfs(i)

print(count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15252\3303967120.py in <module>
#       3 input = sys.stdin.readline
#       4
# ----> 5 n, m = map(int,input().split())
#       6
#       7 graph = [[] for _ in range(n+1)]
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
import sys
sys.setrecursionlimit(10**7)
input = sys.stdin.readline

n,m = map(int,input().split())

graph = [[] for _ in range(n+1)]
visited = [0] * (n+1)

for _ in range(m):
    x, y = map(int, input().split())
    graph[x].append(y)
    graph[y].append(x)

def DFS(x):
    visited[x]=1
    for i in graph[x]:
        if visited[i]==0:
            visited[i]==1
            DFS(i)

count=0
for i in range(1, n+1):
    if visited[i] == 0:
        count+=1
        DFS(i)

print(count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15252\975709987.py in <module>
#       3 input = sys.stdin.readline
#       4
# ----> 5 n,m = map(int,input().split())
#       6
#       7 graph = [[] for _ in range(n+1)]
#
# ValueError: not enough values to unpack (expected 2, got 0)
