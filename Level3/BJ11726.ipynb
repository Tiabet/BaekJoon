# %% [markdown]
# ![image.png](attachment:7076a758-2027-415e-bfda-a7ae510a7869.png)

# %% [markdown]
# 딱 봐도 다이나믹 프로그래밍을 이용해 값을 모두 저장해나가는 문제다. 규칙만 찾으면 쉽게 풀 수 있다.

# %%
n = int(input())

d = [0]*1001

d[1]=1
d[2]=2

for i in range(3,n+1):
    d[i] = d[i-1]+d[i-2]
    
print(d[n]%10007)
# Out:
#  9
# 55

# %% [markdown]
# 이유는 모르겠는데 규칙이 피보나치 수열로 나옴을 찾을 수 있었다. 그리고 다시 생각해보니 타일 하나를 추가하는 경우와 두개를 추가하는 경우로 나누면 되는 것을 깨달을 수 있었다.
