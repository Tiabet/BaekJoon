# %% [markdown]
# ![image.png](attachment:a8cb2859-4750-42dd-9738-1567c07cd8f6.png)

# %% [markdown]
# 이 문제는 배열로 저장하고 정렬해서 풀면 되는 문제 같다. 원리가 그리디 알고리즘하고 똑같다.

# %%
n = int(input())

lst = list(map(int,input().split()))

lst.sort()

time = 0

for i in range(n):
    tmp = 0
    for j in range(i+1):
        tmp += lst[j]
    time+=tmp

print(time)
# Out:
#  5
#  3 1 4 3 2
# 0
# 0
# 1
# 0
# 1
# 3
# 0
# 1
# 3
# 6
# 0
# 1
# 3
# 6
# 9
# 32
