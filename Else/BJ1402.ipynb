# %%
for _ in range(int(input())):
    A, B = map(int, input().split())
    print("yes")
# Out:
#  2
#  14 9
# yes
#  55 1
# no

# %% [markdown]
# ![image.png](attachment:12d0f24e-4a93-48ba-ab4d-911b03bbd4d5.png)

# %% [markdown]
# 알고보니 함정이 있는 문제였다..
