# %% [markdown]
# ![image.png](attachment:eac09a78-181d-4a7a-9e62-29f49bf6d7fd.png)

# %% [markdown]
# 좌표를 정렬하는 문젠데, 이번엔 y좌표를 기준으로 정렬한다.

# %%
n = int(input())
result = []

for _ in range(n):
    x,y = map(int,input().split())
    result.append([x,y])
    
result.sort(key=lambda x : (x[1],x[0]))

for i in range(n):
    print(result[i][0],result[i][1])
