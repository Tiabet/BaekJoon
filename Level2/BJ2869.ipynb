# %% [markdown]
# ![image.png](attachment:c4dfa5bd-bea8-4110-9496-10c62c8b1c18.png)

# %% [markdown]
# 수학 문제를 푸는 듯한 느낌의 문제다.

# %%
a, b, v = map(int, input().split())

days = (v - b - 1) // (a - b) + 1

print(days)
# Out:
#  2 1 5
# 4
