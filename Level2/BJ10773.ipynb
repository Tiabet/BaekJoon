# %% [markdown]
# ![image.png](attachment:464ee609-327f-4af1-87de-1ab612ffff45.png)

# %% [markdown]
# 0이 들어올 때마다 stack에 pop을 하면 문제를 풀 수 있을 것 같다.

# %%
n = int(input())

stack = []

for _ in range(n):
    num = int(input())
    if num == 0:
        stack.pop()
    else:
        stack.append(num)
    
print(sum(stack))
# Out:
#  4
#  4
#  0
#  3
#  0
# 0
