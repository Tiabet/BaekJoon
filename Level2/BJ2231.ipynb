# %% [markdown]
# ![image.png](attachment:720a3f7a-1f3f-49c4-93fc-08f4d82108d1.png)

# %%
n = int(input())
result = 0
for i in range(1, n+1):
    s = i + sum(map(int, str(i)))
    if s == n:
        result = i
        break
print(result)
# Out:
#  216
# 198

# %% [markdown]
# 브루트포스 알고리즘을 이용해 푸는 문제였고, 파이썬에선 map 함수를 이용해 간단하게 문자열을 분해할 수 있다.
