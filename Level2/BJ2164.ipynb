# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 굉장히 신기한 문제다. 아무튼 맨 위의 카드를 한장씩 버리고 다음엔 맨 위의 카드를 맨 아래로 가져오는 매커니즘이니 코딩하기는 어렵지 않을 것 같다.

# %%
from collections import deque

n = int(input())

dq = deque(range(n,0,-1))

while len(dq)!=1:
    dq.pop()
    dq.appendleft(dq.pop())
    
print(dq[0])
# Out:
# 6
# deque([2, 6, 5, 4, 3])
# deque([4, 2, 6, 5])
# deque([6, 4, 2])
# deque([4, 6])
# deque([4])
# 4
