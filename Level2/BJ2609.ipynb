# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 최대공약수, 최소공배수를 구하는 쉬운 문제다.

# %%
a, b = map(int, input().split())

# 최대 공약수 계산
def gcd(a, b):
    if b == 0:
        return a
    return gcd(b, a%b)

gcd_value = gcd(a, b)

# 최소 공배수 계산
lcm_value = int(a * b / gcd_value)

print(gcd_value)
print(lcm_value)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18060\201527086.py in <module>
# ----> 1 a, b = map(int, input().split())
#       2
#       3 # 최대 공약수 계산
#       4 def gcd(a, b):
#       5     if b == 0:
#
# C:\Anaconda\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# C:\Anaconda\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
