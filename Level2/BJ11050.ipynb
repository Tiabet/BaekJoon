# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 이항계수를 구하면 되는 간단한 문제다.

# %%
n, k = map(int, input().split())

def binomial(x,k):
    result = 1
    for i in range (x,(x-k),-1):
        result*=i
    for j in range(2,k+1):
        result/=j
    return int(result)

print(binomial(n,k))
# Out:
# 5 2
# 10

# %% [markdown]
# 깔끔하진 않지만 반복문을 이용해 풀 수 있었다.
